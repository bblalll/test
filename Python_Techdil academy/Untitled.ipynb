# %%
print("*****************\nkullanıcı girişi\n*****************\n")
print("***\ngiriş hakkınız.3\n***\n")
print("""çıkmak için 'q' tuşuna basın""")

sys_kul_ad = "bilal"
sys_parola = "97531"

giriş_hakkı= 3
while True:
    
    kullanıcı_ad = input("kullanıcı adı:")
    parola = input("parola:")
    
    if(kullanıcı_ad and parola == "q"):
        print("programdan çıkılıyor")
        
        break
       
    
    
    elif(kullanıcı_ad == sys_kul_ad and parola != sys_parola):
        print("parola hatalı...")
        giriş_hakkı-=1
        print(" giriş hakkı:", giriş_hakkı)
        
   
        
    elif(kullanıcı_ad != sys_kul_ad and parola == sys_parola):
        print("kullanıcı_ad hatalı...")
        giriş_hakkı-=1
        print(" giriş hakkı:", giriş_hakkı)
        
        
    elif (kullanıcı_ad != sys_kul_ad and parola != sys_parola):
        print("kullanıcı_ad ve parola hatalı...")
        giriş_hakkı-=1
        print(" giriş hakkı:", giriş_hakkı)
        print("""
******************************************
*****************************************
""")

 
    
            
    else:
        print("başarıyla giriş yaptınız:")
        
        print("*************************\na temiyehoş geldiniz\n*************************")
       

        

   
        print("""

işleminizi yapın:

1.bakiye:

2.yatırım:

3.çekme:

geri dönmek için 'q' tuşuna basın

          """)
        bakiye = 1000
        while True:
            işlem = input("işleminizi girin...")
    
            if(işlem == "q"):
                print("yine bekleriz...")
                break

            elif (işlem == "1"):
                print("bakiyeniz {} tl dir".format(bakiye))
        
            elif(işlem == "2"):
                
                miktar = int(input("ytırımınız para:"))
                bakiye += miktar
                print("bakiyeniz {} tl dir".format(bakiye))    
          
        
    
    
            elif(işlem == "3"):
                miktar = int(input("çektiniz para:"))
                bakiye -= miktar
                print("bakiyeniz {} tl dir".format(bakiye))    
           
         
        
                if(bakiye - miktar < 0):
                    print("bu parayı çekemez siniz...")
                    print("bakiyeniz {} tl dir".format(bakiye))
                    continue
        
                bakiye -= miktar
            else:
                print("lütfen geçerliişlem girin.....")
                

 
    if (giriş_hakkı == 0):
        
        
        
        print("giriş hakkınız bitti...")
        
        break
# Out:
# *****************
# kullanıcı girişi
# *****************
#
# ***
# giriş hakkınız.3
# ***
#
# çıkmak için 'q' tuşuna basın
# kullanıcı adı:4
# parola:3
# kullanıcı_ad ve parola hatalı...
#  giriş hakkı: 2
#
# ******************************************
# *****************************************
#
# kullanıcı adı:4
# parola:
# kullanıcı_ad ve parola hatalı...
#  giriş hakkı: 1
#
# ******************************************
# *****************************************
#
# kullanıcı adı:4568
# parola:456
# kullanıcı_ad ve parola hatalı...
#  giriş hakkı: 0
#
# ******************************************
# *****************************************
#
# giriş hakkınız bitti...
